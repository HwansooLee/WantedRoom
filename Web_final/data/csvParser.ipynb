# %%
# read csv file in pandas
import pandas as pd
data = pd.read_csv('storeData.csv', encoding='euc-kr')
data = data[['도로명전체주소', '사업장명', '좌표정보(x)', '좌표정보(y)']]
data
# Out:
#                         도로명전체주소               사업장명        좌표정보(x)
# 0         대구광역시 북구 검단로 97 (산격동)           코스트코 홀세일  346013.651465  \
# 1      대구광역시 북구 팔달로 183 (노원동2가)              하나프러스  341722.529953
# 2       대구광역시 북구 유통단지로 16 (산격동)        대구기계공구상협동조합  344912.358902
# 3       대구광역시 북구 유통단지로 38 (산격동)     대구종합유통단지 전기재료관  345062.754182
# 4     대구광역시 북구 칠곡중앙대로 412 (태전동)            네오시티프라자  339707.015975
# ...                         ...                ...            ...
# 3935     강원도 속초시 조양상가길 25 (조양동)               D-마트  338339.974553
# 3936   충청남도 보령시 대천항중앙길 66 (신흑동)  (사)한국수산업경영인보령시연합회  155664.029856
# 3937   충청남도 보령시 대천항중앙길 66 (신흑동)  (사)한국수산업경영인보령시연합회  155664.029856
# 3938                        NaN            (주)세계유통            NaN
# 3939                        NaN                애플존  282066.471631
#
#             좌표정보(y)
# 0     268532.189936
# 1     266512.649171
# 2     268253.830253
# 3     268408.951404
# 4     271331.088251
# ...             ...
# 3935  521995.523481
# 3936  314155.428629
# 3937  314155.428629
# 3938            NaN
# 3939  387630.151702
#
# [3940 rows x 4 columns]

# %%
# add Pandas to oracle DB
# can't connect with oracledb to oracle 11g
import oracledb
conn = oracledb.connect(
    user='final',
    password='1111',
    dsn='localhost:1521/orcl'
)
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 # add Pandas to oracle DB
#       2 import oracledb
# ----> 3 conn = oracledb.connect(
#       4     user='final',
#       5     password='1111',
#       6     dsn='localhost:1521/orcl'
#       7 )
#
# File c:\Users\admin\anaconda3\envs\my-env\Lib\site-packages\oracledb\connection.py:1008, in _connection_factory.<locals>.connect(dsn, pool, conn_class, params, **kwargs)
#    1006 if not issubclass(conn_class, Connection):
#    1007     errors._raise_err(errors.ERR_INVALID_CONN_CLASS)
# -> 1008 return conn_class(dsn=dsn, pool=pool, params=params, **kwargs)
#
# File c:\Users\admin\anaconda3\envs\my-env\Lib\site-packages\oracledb\connection.py:130, in Connection.__init__(self, dsn, pool, params, **kwargs)
#     128     else:
#     129         impl = thin_impl.ThinConnImpl(dsn, params_impl)
# --> 130         impl.connect(params_impl)
#     131 else:
#     132     impl = thick_impl.ThickConnImpl(dsn, params_impl)
#
# File src\oracledb\impl/thin/connection.pyx:313, in oracledb.thin_impl.ThinConnImpl.connect()
#
# File src\oracledb\impl/thin/connection.pyx:202, in oracledb.thin_impl.ThinConnImpl._connect_with_params()
#
# File src\oracledb\impl/thin/connection.pyx:173, in oracledb.thin_impl.ThinConnImpl._connect_with_description()
#
# File src\oracledb\impl/thin/connection.pyx:114, in oracledb.thin_impl.ThinConnImpl._connect_with_address()
#
# File src\oracledb\impl/thin/protocol.pyx:213, in oracledb.thin_impl.Protocol._connect_phase_two()
#
# File c:\Users\admin\anaconda3\envs\my-env\Lib\site-packages\oracledb\errors.py:118, in _raise_err(error_num, context_error_message, cause, **args)
#     116     message = f"{message}\n{context_error_message}"
#     117 exc_type = ERR_EXCEPTION_TYPES[error_num // 1000]
# --> 118 raise exc_type(_Error(message)) from cause
#
# NotSupportedError: DPY-3010: connections to this database server version are not supported by python-oracledb in thin mode

# %%
# make data 22 from data
data33 = pd.read_csv('06population_number.csv', encoding='euc-kr')
data33.index = data33['도시']
del data33['도시']
data33
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
# 3. data를 data1로 복사하시오. 결측치는 1000000으로 입력하시오.
data1 = data.fillna(value=1000000)
print(data1)
# Out:
#    도시   지역     2015       2010       2005     2000
# 0  서울  수도권  9904312  9631482.0  9762546.0  9853972
# 1  부산  경상권  3448737  1000000.0  1000000.0  3655437
# 2  인천  수도권  2890451  2632035.0  1000000.0  2466338
# 3  대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
# data2로 만들어 작업
# 7. 2010년 자료에서 결측치를 제거하고 평균을 구하시오. 평균을 결측치에 채우시오.
YEAR = '2010'
# avg = data[YEAR].sum() / data[YEAR].notnull().value_counts()[True]
avg = data[YEAR].mean()
data2 = data
data2[YEAR] = data[YEAR].fillna( int(avg))
data2
# Out:
#    도시   지역     2015       2010       2005     2000
# 0  서울  수도권  9904312  9631482.0  9762546.0  9853972
# 1  부산  경상권  3448737  4898430.0        NaN  3655437
# 2  인천  수도권  2890451  2632035.0        NaN  2466338
# 3  대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
# 8. 2005년 자료에서 결측치를 제거하고 평균을 구하시오. 평균을 결측치에 채우시오.
YEAR = '2005'
# avg = data[YEAR].sum() / data[YEAR].notnull().value_counts()[True]
avg = data[YEAR].mean()
data2[YEAR] = data[YEAR].fillna( int(avg))
data2
# Out:
#    도시   지역     2015       2010       2005     2000
# 0  서울  수도권  9904312  9631482.0  9762546.0  9853972
# 1  부산  경상권  3448737  4898430.0  6109281.0  3655437
# 2  인천  수도권  2890451  2632035.0  6109281.0  2466338
# 3  대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
# apply() for max - min and make diff column
data3 = data2
# using lambda
data3['diff'] = data3[['2000', '2005', '2010', '2015']].apply(lambda x: max(x)-min(x), axis=1)
# define own function
def diff(x):
    return max(x) - min(x)
data3['diff'] = data3[['2000', '2005', '2010', '2015']].apply(diff, axis=1)
data3
# Out:
#    도시   지역     2015       2010       2005     2000       diff
# 0  서울  수도권  9904312  9631482.0  9762546.0  9853972   272830.0
# 1  부산  경상권  3448737  4898430.0  6109281.0  3655437  2660544.0
# 2  인천  수도권  2890451  2632035.0  6109281.0  2466338  3642943.0
# 3  대구  경상권  2466052  2431774.0  2456016.0  2473990    42216.0
